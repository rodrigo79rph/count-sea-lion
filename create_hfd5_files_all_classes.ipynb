# %%
import pickle
from collections import namedtuple
import numpy as np
import cv2
import os
import matplotlib.image as mpimg
import h5py
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import random
from glob import glob

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
TRAIN_DIR_IMGS = '../data/Train/'
TRAIN_DIR_DOTTED_IMGS = '../data/TrainDotted/'
NUM_TRAIN_IMGS = 948
NUM_VAL_IMGS = 70

PATCH_SIZE = 256
PAD_SIZE = 16
NEG_RATIO = 0.02

WITH_PUPS = True

TEST_DIR_IMGS = '../data/Test/'

# %%
SeaLionCoord = namedtuple('SeaLionCoord', ['img_id', 'x', 'y', 'cls'])

# %%
COLORS = (  (243, 8, 5),          # red
            (244, 8, 242),        # magenta
            (87, 46, 10),         # brown
            (25, 56, 176),        # blue
            (38, 174, 21),        # green
)

# %%
BAD_IMGS = [3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234,
            242, 268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490,
            499, 507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721,
            767, 779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905,
            909, 913, 927, 946, 912, 66, 235, 292, 426, 529, 593, 643, 816, 857]

# %%
ID_IMGS = []
for i in range(NUM_TRAIN_IMGS):
    if i not in BAD_IMGS:
        ID_IMGS.append(i)
ID_IMGS = shuffle(ID_IMGS)
print(len(ID_IMGS))
# Out:
# 881

# %%
ID_TRAIN_IMGS = ID_IMGS[NUM_VAL_IMGS:]
ID_VAL_IMGS = ID_IMGS[:NUM_VAL_IMGS]

# %%
train_h5py = h5py.File("data/train_all_classes.h5",mode='w')
dset_target_imgs = train_h5py.create_dataset("target_imgs", (0, PATCH_SIZE + 2*PAD_SIZE, PATCH_SIZE + 2*PAD_SIZE, 1),
                                             maxshape=(None, PATCH_SIZE + 2*PAD_SIZE, PATCH_SIZE + 2*PAD_SIZE, 1),
                                             dtype=np.uint8, shuffle=True, compression="gzip")

dset_imgs = train_h5py.create_dataset("imgs", (0, PATCH_SIZE, PATCH_SIZE, 3),
                                      maxshape=(None, PATCH_SIZE, PATCH_SIZE, 3),
                                      dtype=np.uint8, shuffle=True, compression="gzip")

dset_counts = train_h5py.create_dataset("counts", (0,), maxshape=(None,),
                                        dtype=np.uint8, shuffle=True, compression="gzip")

# %%
def neighbourhood(xs, ys):
    return sum((x-y)**2 for x, y in zip(xs, ys)) > 300
        
def remove_neighbourhood(data, cond):
    coords = []
    for element in data:
        if all(cond(element, other) for other in coords):
            coords.append(element)
    return coords

# %%
def remove_some_negative(x, y, c, negative_ratio=1.0):
    win_mask = c != 0
    los_mask = c == 0

    win_x = x[win_mask]
    win_y = y[win_mask]
    win_c = c[win_mask]
    los_x = x[los_mask]
    los_y = y[los_mask]
    los_c = c[los_mask]

    order = np.random.permutation(los_c.shape[0])
    amt = int(win_c.shape[0]*negative_ratio)
    los_x = los_x[order][0:amt]
    los_y = los_y[order][0:amt]
    los_c = los_c[order][0:amt]

    both_x = np.concatenate([win_x, los_x])
    both_y = np.concatenate([win_y, los_y])
    both_c = np.concatenate([win_c, los_c])
    order = np.random.permutation(both_c.shape[0])

    return both_x[order], both_y[order], both_c[order]

# %%
def create_datasets(LIST_IDS, DSET_target_imgs, DSET_imgs, DSET_counts): 
    for ID in LIST_IDS: 
        print("\tProcessing sample dset_target_imgs, with id={}".format(ID))
        img = mpimg.imread(os.path.join(TRAIN_DIR_IMGS,"{}.jpg".format(ID)))
        dotted_img = mpimg.imread(os.path.join(TRAIN_DIR_DOTTED_IMGS, "{}.jpg".format(ID)))

        # extract coordinates of animals : 
        diff = cv2.subtract(img, dotted_img)
        diff[dotted_img < 30] = 0
        x, y = np.where(np.any(diff > 60, axis=2))
        xy = zip(x, y)
        coords = remove_neighbourhood(xy, neighbourhood)
        sealioncoords = [ SeaLionCoord(100, x, y, np.argmin(np.linalg.norm(COLORS - dotted_img[x, y], axis=1)))
                         for x, y in coords]

        # make regular crops of size PATHCH_SIZE
        n_x = img.shape[0] // PATCH_SIZE
        n_y = img.shape[1] // PATCH_SIZE
        x_rem = img.shape[0] % PATCH_SIZE
        y_rem = img.shape[1] % PATCH_SIZE

        imgs = []
        target_imgs = []
        counts = []

        for x in range(n_x + (x_rem > 0)):
            for y in range(n_y + (y_rem > 0)):
                count = 0
                xmin = x*PATCH_SIZE
                ymin = y*PATCH_SIZE
                xmax = xmin+PATCH_SIZE
                ymax = ymin+PATCH_SIZE

                new_img = img[xmin:xmax, ymin:ymax]

                # Edge case
                if x == n_x or y == n_y:
                    temp = np.zeros((PATCH_SIZE, PATCH_SIZE, 3), dtype=np.uint8)
                    temp[:new_img.shape[0], :new_img.shape[1], :] = new_img
                    new_img = temp

                target_img = np.zeros((PATCH_SIZE + 2*PAD_SIZE, PATCH_SIZE + 2*PAD_SIZE), dtype=np.uint8)

                for i in sealioncoords:
                    if i.cls == 4 and not WITH_PUPS: # Skip pups
                        continue

                    # In 256x256-coords
                    unpad_x = i.x - xmin
                    unpad_y = i.y - ymin
                    if unpad_x < 0 or unpad_y < 0 or unpad_x >= PATCH_SIZE or unpad_y >= PATCH_SIZE:
                        continue

                    # In 288x288-coords
                    pad_x = unpad_x + PAD_SIZE
                    pad_y = unpad_y + PAD_SIZE
                    assert pad_x - PAD_SIZE >= 0
                    assert pad_x + PAD_SIZE < PATCH_SIZE + 2*PAD_SIZE
                    assert pad_y - PAD_SIZE >= 0
                    assert pad_y + PAD_SIZE < PATCH_SIZE + 2*PAD_SIZE

                    target_img[(pad_x - PAD_SIZE):(pad_x + PAD_SIZE), (pad_y - PAD_SIZE):(pad_y + PAD_SIZE)] += 1
                    count += 1

                imgs.append(new_img)
                target_imgs.append(target_img)
                counts.append(count)

        # convert imgs, target_imgs and counts into numpy arrays :
        imgs = np.asarray(imgs, dtype=np.uint8)
        target_imgs = np.asarray(target_imgs, dtype=np.uint8)
        counts = np.asarray(counts, dtype=np.uint8)
        
        # keep only 5% of blanck patches ! 
        imgs, target_imgs, counts = remove_some_negative(imgs, target_imgs, counts, negative_ratio=NEG_RATIO)
        num_new_samples = imgs.shape[0]
        if num_new_samples > 0 :
            # add these elements to the datasets : 
            DSET_target_imgs.resize(DSET_target_imgs.shape[0] + num_new_samples, axis=0)
            DSET_target_imgs[-num_new_samples:] = np.expand_dims(target_imgs, axis=-1)

            DSET_imgs.resize(DSET_imgs.shape[0] + num_new_samples, axis=0)
            DSET_imgs[-num_new_samples:] = imgs

            DSET_counts.resize(DSET_counts.shape[0] + num_new_samples, axis=0)
            DSET_counts[-num_new_samples:] = counts

# %%
# %%time

create_datasets(ID_TRAIN_IMGS, dset_target_imgs, dset_imgs, dset_counts)
print(dset_imgs.shape)
print(dset_target_imgs.shape)
print(dset_counts.shape)
# Out:
# 	Processing sample dset_target_imgs, with id=745
# 	Processing sample dset_target_imgs, with id=815
# 	Processing sample dset_target_imgs, with id=205
# 	Processing sample dset_target_imgs, with id=288
# 	Processing sample dset_target_imgs, with id=437
# 	Processing sample dset_target_imgs, with id=863
# 	Processing sample dset_target_imgs, with id=82
# 	Processing sample dset_target_imgs, with id=64
# 	Processing sample dset_target_imgs, with id=484
# 	Processing sample dset_target_imgs, with id=683
# 	Processing sample dset_target_imgs, with id=346
# 	Processing sample dset_target_imgs, with id=390
# 	Processing sample dset_target_imgs, with id=491
# 	Processing sample dset_target_imgs, with id=451
# 	Processing sample dset_target_imgs, with id=428
# 	Processing sample dset_target_imgs, with id=369
# 	Processing sample dset_target_imgs, with id=313
# 	Processing sample dset_target_imgs, with id=798
# 	Processing sample dset_target_imgs, with id=200
# 	Processing sample dset_target_imgs, with id=158
# 	Processing sample dset_target_imgs, with id=85
# 	Processing sample dset_target_imgs, with id=470
# 	Processing sample dset_target_imgs, with id=2
# 	Processing sample dset_target_imgs, with id=252
# 	Processing sample dset_target_imgs, with id=193
# 	Processing sample dset_target_imgs, with id=488
# 	Processing sample dset_target_imgs, with id=119
# 	Processing sample dset_target_imgs, with id=647
# 	Processing sample dset_target_imgs, with id=578
# 	Processing sample dset_target_imgs, with id=872
# 	Processing sample dset_target_imgs, with id=523
# 	Processing sample dset_target_imgs, with id=127
# 	Processing sample dset_target_imgs, with id=500
# 	Processing sample dset_target_imgs, with id=826
# 	Processing sample dset_target_imgs, with id=189
# 	Processing sample dset_target_imgs, with id=538
# 	Processing sample dset_target_imgs, with id=925
# 	Processing sample dset_target_imgs, with id=402
# 	Processing sample dset_target_imgs, with id=581
# 	Processing sample dset_target_imgs, with id=890
# 	Processing sample dset_target_imgs, with id=942
# 	Processing sample dset_target_imgs, with id=597
# 	Processing sample dset_target_imgs, with id=741
# 	Processing sample dset_target_imgs, with id=239
# 	Processing sample dset_target_imgs, with id=263
# 	Processing sample dset_target_imgs, with id=668
# 	Processing sample dset_target_imgs, with id=135
# 	Processing sample dset_target_imgs, with id=823
# 	Processing sample dset_target_imgs, with id=449
# 	Processing sample dset_target_imgs, with id=908
# 	Processing sample dset_target_imgs, with id=281
# 	Processing sample dset_target_imgs, with id=694
# 	Processing sample dset_target_imgs, with id=10
# 	Processing sample dset_target_imgs, with id=434
# 	Processing sample dset_target_imgs, with id=130
# 	Processing sample dset_target_imgs, with id=134
# 	Processing sample dset_target_imgs, with id=742
# 	Processing sample dset_target_imgs, with id=20
# 	Processing sample dset_target_imgs, with id=910
# 	Processing sample dset_target_imgs, with id=415
# 	Processing sample dset_target_imgs, with id=658
# 	Processing sample dset_target_imgs, with id=642
# 	Processing sample dset_target_imgs, with id=655
# 	Processing sample dset_target_imgs, with id=626
# 	Processing sample dset_target_imgs, with id=155
# 	Processing sample dset_target_imgs, with id=652
# 	Processing sample dset_target_imgs, with id=357
# 	Processing sample dset_target_imgs, with id=684
# 	Processing sample dset_target_imgs, with id=258
# 	Processing sample dset_target_imgs, with id=139
# 	Processing sample dset_target_imgs, with id=898
# 	Processing sample dset_target_imgs, with id=480
# 	Processing sample dset_target_imgs, with id=108
# 	Processing sample dset_target_imgs, with id=123
# 	Processing sample dset_target_imgs, with id=154
# 	Processing sample dset_target_imgs, with id=556
# 	Processing sample dset_target_imgs, with id=747
# 	Processing sample dset_target_imgs, with id=926
# 	Processing sample dset_target_imgs, with id=84
# 	Processing sample dset_target_imgs, with id=430
# 	Processing sample dset_target_imgs, with id=476
# 	Processing sample dset_target_imgs, with id=63
# 	Processing sample dset_target_imgs, with id=894
# 	Processing sample dset_target_imgs, with id=411
# 	Processing sample dset_target_imgs, with id=730
# 	Processing sample dset_target_imgs, with id=924
# 	Processing sample dset_target_imgs, with id=824
# 	Processing sample dset_target_imgs, with id=907
# 	Processing sample dset_target_imgs, with id=874
# 	Processing sample dset_target_imgs, with id=27
# 	Processing sample dset_target_imgs, with id=86
# 	Processing sample dset_target_imgs, with id=11
# 	Processing sample dset_target_imgs, with id=87
# 	Processing sample dset_target_imgs, with id=216
# 	Processing sample dset_target_imgs, with id=136
# 	Processing sample dset_target_imgs, with id=518
# 	Processing sample dset_target_imgs, with id=385
# 	Processing sample dset_target_imgs, with id=799
# 	Processing sample dset_target_imgs, with id=231
# 	Processing sample dset_target_imgs, with id=270
# 	Processing sample dset_target_imgs, with id=810
# 	Processing sample dset_target_imgs, with id=603
# 	Processing sample dset_target_imgs, with id=885
# 	Processing sample dset_target_imgs, with id=704
# 	Processing sample dset_target_imgs, with id=256
# 	Processing sample dset_target_imgs, with id=744
# 	Processing sample dset_target_imgs, with id=726
# 	Processing sample dset_target_imgs, with id=345
# 	Processing sample dset_target_imgs, with id=196
# 	Processing sample dset_target_imgs, with id=535
# 	Processing sample dset_target_imgs, with id=447
# 	Processing sample dset_target_imgs, with id=222
# 	Processing sample dset_target_imgs, with id=17
# 	Processing sample dset_target_imgs, with id=858
# 	Processing sample dset_target_imgs, with id=317
# 	Processing sample dset_target_imgs, with id=847
# 	Processing sample dset_target_imgs, with id=780
# 	Processing sample dset_target_imgs, with id=648
# 	Processing sample dset_target_imgs, with id=37
# 	Processing sample dset_target_imgs, with id=465
# 	Processing sample dset_target_imgs, with id=566
# 	Processing sample dset_target_imgs, with id=201
# 	Processing sample dset_target_imgs, with id=283
# 	Processing sample dset_target_imgs, with id=416
# 	Processing sample dset_target_imgs, with id=350
# 	Processing sample dset_target_imgs, with id=133
# 	Processing sample dset_target_imgs, with id=574
# 	Processing sample dset_target_imgs, with id=892
# 	Processing sample dset_target_imgs, with id=855
# 	Processing sample dset_target_imgs, with id=817
# 	Processing sample dset_target_imgs, with id=732
# 	Processing sample dset_target_imgs, with id=654
# 	Processing sample dset_target_imgs, with id=228
# 	Processing sample dset_target_imgs, with id=373
# 	Processing sample dset_target_imgs, with id=138
# 	Processing sample dset_target_imgs, with id=432
# 	Processing sample dset_target_imgs, with id=669
# 	Processing sample dset_target_imgs, with id=340
# 	Processing sample dset_target_imgs, with id=646
# 	Processing sample dset_target_imgs, with id=527
# 	Processing sample dset_target_imgs, with id=656
# 	Processing sample dset_target_imgs, with id=249
# 	Processing sample dset_target_imgs, with id=1
# 	Processing sample dset_target_imgs, with id=194
# 	Processing sample dset_target_imgs, with id=624
# 	Processing sample dset_target_imgs, with id=70
# 	Processing sample dset_target_imgs, with id=118
# 	Processing sample dset_target_imgs, with id=414
# 	Processing sample dset_target_imgs, with id=363
# 	Processing sample dset_target_imgs, with id=259
# 	Processing sample dset_target_imgs, with id=764
# 	Processing sample dset_target_imgs, with id=630
# 	Processing sample dset_target_imgs, with id=613
# 	Processing sample dset_target_imgs, with id=617
# 	Processing sample dset_target_imgs, with id=129
# 	Processing sample dset_target_imgs, with id=576
# 	Processing sample dset_target_imgs, with id=544
# 	Processing sample dset_target_imgs, with id=261
# 	Processing sample dset_target_imgs, with id=379
# 	Processing sample dset_target_imgs, with id=318
# 	Processing sample dset_target_imgs, with id=78
# 	Processing sample dset_target_imgs, with id=336
# 	Processing sample dset_target_imgs, with id=371
# 	Processing sample dset_target_imgs, with id=388
# 	Processing sample dset_target_imgs, with id=571
# 	Processing sample dset_target_imgs, with id=289
# 	Processing sample dset_target_imgs, with id=690
# 	Processing sample dset_target_imgs, with id=577
# 	Processing sample dset_target_imgs, with id=526
# 	Processing sample dset_target_imgs, with id=377
# 	Processing sample dset_target_imgs, with id=834
# 	Processing sample dset_target_imgs, with id=145
# 	Processing sample dset_target_imgs, with id=227
# 	Processing sample dset_target_imgs, with id=637
# 	Processing sample dset_target_imgs, with id=362
# 	Processing sample dset_target_imgs, with id=569
# 	Processing sample dset_target_imgs, with id=486
# 	Processing sample dset_target_imgs, with id=676
# 	Processing sample dset_target_imgs, with id=752
# 	Processing sample dset_target_imgs, with id=879
# 	Processing sample dset_target_imgs, with id=31
# 	Processing sample dset_target_imgs, with id=510
# 	Processing sample dset_target_imgs, with id=774
# 	Processing sample dset_target_imgs, with id=68
# 	Processing sample dset_target_imgs, with id=212
# 	Processing sample dset_target_imgs, with id=786
# 	Processing sample dset_target_imgs, with id=609
# 	Processing sample dset_target_imgs, with id=291
# 	Processing sample dset_target_imgs, with id=625
# 	Processing sample dset_target_imgs, with id=179
# 	Processing sample dset_target_imgs, with id=403
# 	Processing sample dset_target_imgs, with id=312
# 	Processing sample dset_target_imgs, with id=592
# 	Processing sample dset_target_imgs, with id=280
# 	Processing sample dset_target_imgs, with id=536
# 	Processing sample dset_target_imgs, with id=773
# 	Processing sample dset_target_imgs, with id=833
# 	Processing sample dset_target_imgs, with id=433
# 	Processing sample dset_target_imgs, with id=314
# 	Processing sample dset_target_imgs, with id=664
# 	Processing sample dset_target_imgs, with id=122
# 	Processing sample dset_target_imgs, with id=532
# 	Processing sample dset_target_imgs, with id=472
# 	Processing sample dset_target_imgs, with id=392
# 	Processing sample dset_target_imgs, with id=113
# 	Processing sample dset_target_imgs, with id=43
# 	Processing sample dset_target_imgs, with id=477
# 	Processing sample dset_target_imgs, with id=358
# 	Processing sample dset_target_imgs, with id=541
# 	Processing sample dset_target_imgs, with id=264
# 	Processing sample dset_target_imgs, with id=233
# 	Processing sample dset_target_imgs, with id=38
# 	Processing sample dset_target_imgs, with id=947
# 	Processing sample dset_target_imgs, with id=265
# 	Processing sample dset_target_imgs, with id=400
# 	Processing sample dset_target_imgs, with id=867
# 	Processing sample dset_target_imgs, with id=375
# 	Processing sample dset_target_imgs, with id=821
# 	Processing sample dset_target_imgs, with id=877
# 	Processing sample dset_target_imgs, with id=522
# 	Processing sample dset_target_imgs, with id=418
# 	Processing sample dset_target_imgs, with id=599
# 	Processing sample dset_target_imgs, with id=278
# 	Processing sample dset_target_imgs, with id=716
# 	Processing sample dset_target_imgs, with id=825
# 	Processing sample dset_target_imgs, with id=735
# 	Processing sample dset_target_imgs, with id=517
# 	Processing sample dset_target_imgs, with id=343
# 	Processing sample dset_target_imgs, with id=904
# 	Processing sample dset_target_imgs, with id=156
# 	Processing sample dset_target_imgs, with id=902
# 	Processing sample dset_target_imgs, with id=661
# 	Processing sample dset_target_imgs, with id=395
# 	Processing sample dset_target_imgs, with id=98
# 	Processing sample dset_target_imgs, with id=547
# 	Processing sample dset_target_imgs, with id=906
# 	Processing sample dset_target_imgs, with id=161
# 	Processing sample dset_target_imgs, with id=662
# 	Processing sample dset_target_imgs, with id=370
# 	Processing sample dset_target_imgs, with id=844
# 	Processing sample dset_target_imgs, with id=580
# 	Processing sample dset_target_imgs, with id=191
# 	Processing sample dset_target_imgs, with id=319
# 	Processing sample dset_target_imgs, with id=563
# 	Processing sample dset_target_imgs, with id=211
# 	Processing sample dset_target_imgs, with id=729
# 	Processing sample dset_target_imgs, with id=933
# 	Processing sample dset_target_imgs, with id=275
# 	Processing sample dset_target_imgs, with id=221
# 	Processing sample dset_target_imgs, with id=836
# 	Processing sample dset_target_imgs, with id=568
# 	Processing sample dset_target_imgs, with id=513
# 	Processing sample dset_target_imgs, with id=324
# 	Processing sample dset_target_imgs, with id=162
# 	Processing sample dset_target_imgs, with id=250
# 	Processing sample dset_target_imgs, with id=206
# 	Processing sample dset_target_imgs, with id=178
# 	Processing sample dset_target_imgs, with id=88
# 	Processing sample dset_target_imgs, with id=464
# 	Processing sample dset_target_imgs, with id=423
# 	Processing sample dset_target_imgs, with id=801
# 	Processing sample dset_target_imgs, with id=132
# 	Processing sample dset_target_imgs, with id=700
# 	Processing sample dset_target_imgs, with id=623
# 	Processing sample dset_target_imgs, with id=641
# 	Processing sample dset_target_imgs, with id=105
# 	Processing sample dset_target_imgs, with id=632
# 	Processing sample dset_target_imgs, with id=870
# 	Processing sample dset_target_imgs, with id=770
# 	Processing sample dset_target_imgs, with id=160
# 	Processing sample dset_target_imgs, with id=619
# 	Processing sample dset_target_imgs, with id=103
# 	Processing sample dset_target_imgs, with id=4
# 	Processing sample dset_target_imgs, with id=715
# 	Processing sample dset_target_imgs, with id=364
# 	Processing sample dset_target_imgs, with id=725
# 	Processing sample dset_target_imgs, with id=56
# 	Processing sample dset_target_imgs, with id=177
# 	Processing sample dset_target_imgs, with id=645
# 	Processing sample dset_target_imgs, with id=457
# 	Processing sample dset_target_imgs, with id=217
# 	Processing sample dset_target_imgs, with id=837
# 	Processing sample dset_target_imgs, with id=169
# 	Processing sample dset_target_imgs, with id=424
# 	Processing sample dset_target_imgs, with id=128
# 	Processing sample dset_target_imgs, with id=96
# 	Processing sample dset_target_imgs, with id=111
# 	Processing sample dset_target_imgs, with id=868
# 	Processing sample dset_target_imgs, with id=579
# 	Processing sample dset_target_imgs, with id=897
# 	Processing sample dset_target_imgs, with id=789
# 	Processing sample dset_target_imgs, with id=407
# 	Processing sample dset_target_imgs, with id=695
# 	Processing sample dset_target_imgs, with id=202
# 	Processing sample dset_target_imgs, with id=559
# 	Processing sample dset_target_imgs, with id=69
# 	Processing sample dset_target_imgs, with id=40
# 	Processing sample dset_target_imgs, with id=936
# 	Processing sample dset_target_imgs, with id=214
# 	Processing sample dset_target_imgs, with id=149
# 	Processing sample dset_target_imgs, with id=838
# 	Processing sample dset_target_imgs, with id=320
# 	Processing sample dset_target_imgs, with id=596
# 	Processing sample dset_target_imgs, with id=262
# 	Processing sample dset_target_imgs, with id=338
# 	Processing sample dset_target_imgs, with id=110
# 	Processing sample dset_target_imgs, with id=399
# 	Processing sample dset_target_imgs, with id=548
# 	Processing sample dset_target_imgs, with id=557
# 	Processing sample dset_target_imgs, with id=495
# 	Processing sample dset_target_imgs, with id=856
# 	Processing sample dset_target_imgs, with id=269
# 	Processing sample dset_target_imgs, with id=627
# 	Processing sample dset_target_imgs, with id=253
# 	Processing sample dset_target_imgs, with id=99
# 	Processing sample dset_target_imgs, with id=828
# 	Processing sample dset_target_imgs, with id=137
# 	Processing sample dset_target_imgs, with id=876
# 	Processing sample dset_target_imgs, with id=514
# 	Processing sample dset_target_imgs, with id=483
# 	Processing sample dset_target_imgs, with id=653
# 	Processing sample dset_target_imgs, with id=79
# 	Processing sample dset_target_imgs, with id=282
# 	Processing sample dset_target_imgs, with id=393
# 	Processing sample dset_target_imgs, with id=354
# 	Processing sample dset_target_imgs, with id=92
# 	Processing sample dset_target_imgs, with id=104
# 	Processing sample dset_target_imgs, with id=142
# 	Processing sample dset_target_imgs, with id=295
# 	Processing sample dset_target_imgs, with id=546
# 	Processing sample dset_target_imgs, with id=778
# 	Processing sample dset_target_imgs, with id=564
# 	Processing sample dset_target_imgs, with id=515
# 	Processing sample dset_target_imgs, with id=582
# 	Processing sample dset_target_imgs, with id=391
# 	Processing sample dset_target_imgs, with id=511
# 	Processing sample dset_target_imgs, with id=365
# 	Processing sample dset_target_imgs, with id=680
# 	Processing sample dset_target_imgs, with id=441
# 	Processing sample dset_target_imgs, with id=241
# 	Processing sample dset_target_imgs, with id=209
# 	Processing sample dset_target_imgs, with id=349
# 	Processing sample dset_target_imgs, with id=492
# 	Processing sample dset_target_imgs, with id=713
# 	Processing sample dset_target_imgs, with id=232
# 	Processing sample dset_target_imgs, with id=584
# 	Processing sample dset_target_imgs, with id=347
# 	Processing sample dset_target_imgs, with id=600
# 	Processing sample dset_target_imgs, with id=772
# 	Processing sample dset_target_imgs, with id=751
# 	Processing sample dset_target_imgs, with id=333
# 	Processing sample dset_target_imgs, with id=740
# 	Processing sample dset_target_imgs, with id=213
# 	Processing sample dset_target_imgs, with id=247
# 	Processing sample dset_target_imgs, with id=355
# 	Processing sample dset_target_imgs, with id=294
# 	Processing sample dset_target_imgs, with id=148
# 	Processing sample dset_target_imgs, with id=14
# 	Processing sample dset_target_imgs, with id=58
# 	Processing sample dset_target_imgs, with id=107
# 	Processing sample dset_target_imgs, with id=474
# 	Processing sample dset_target_imgs, with id=768
# 	Processing sample dset_target_imgs, with id=915
# 	Processing sample dset_target_imgs, with id=396
# 	Processing sample dset_target_imgs, with id=519
# 	Processing sample dset_target_imgs, with id=887
# 	Processing sample dset_target_imgs, with id=761
# 	Processing sample dset_target_imgs, with id=124
# 	Processing sample dset_target_imgs, with id=765
# 	Processing sample dset_target_imgs, with id=101
# 	Processing sample dset_target_imgs, with id=889
# 	Processing sample dset_target_imgs, with id=749
# 	Processing sample dset_target_imgs, with id=100
# 	Processing sample dset_target_imgs, with id=875
# 	Processing sample dset_target_imgs, with id=819
# 	Processing sample dset_target_imgs, with id=188
# 	Processing sample dset_target_imgs, with id=604
# 	Processing sample dset_target_imgs, with id=287
# 	Processing sample dset_target_imgs, with id=45
# 	Processing sample dset_target_imgs, with id=219
# 	Processing sample dset_target_imgs, with id=850
# 	Processing sample dset_target_imgs, with id=503
# 	Processing sample dset_target_imgs, with id=787
# 	Processing sample dset_target_imgs, with id=830
# 	Processing sample dset_target_imgs, with id=321
# 	Processing sample dset_target_imgs, with id=813
# 	Processing sample dset_target_imgs, with id=493
# 	Processing sample dset_target_imgs, with id=562
# 	Processing sample dset_target_imgs, with id=383
# 	Processing sample dset_target_imgs, with id=448
# 	Processing sample dset_target_imgs, with id=284
# 	Processing sample dset_target_imgs, with id=941
# 	Processing sample dset_target_imgs, with id=60
# 	Processing sample dset_target_imgs, with id=446
# 	Processing sample dset_target_imgs, with id=35
# 	Processing sample dset_target_imgs, with id=639
# 	Processing sample dset_target_imgs, with id=482
# 	Processing sample dset_target_imgs, with id=409
# 	Processing sample dset_target_imgs, with id=455
# 	Processing sample dset_target_imgs, with id=351
# 	Processing sample dset_target_imgs, with id=49
# 	Processing sample dset_target_imgs, with id=243
# 	Processing sample dset_target_imgs, with id=170
# 	Processing sample dset_target_imgs, with id=671
# 	Processing sample dset_target_imgs, with id=649
# 	Processing sample dset_target_imgs, with id=720
# 	Processing sample dset_target_imgs, with id=185
# 	Processing sample dset_target_imgs, with id=382
# 	Processing sample dset_target_imgs, with id=734
# 	Processing sample dset_target_imgs, with id=46
# 	Processing sample dset_target_imgs, with id=756
# 	Processing sample dset_target_imgs, with id=152
# 	Processing sample dset_target_imgs, with id=688
# 	Processing sample dset_target_imgs, with id=32
# 	Processing sample dset_target_imgs, with id=689
# 	Processing sample dset_target_imgs, with id=220
# 	Processing sample dset_target_imgs, with id=303
# 	Processing sample dset_target_imgs, with id=494
# 	Processing sample dset_target_imgs, with id=784
# 	Processing sample dset_target_imgs, with id=166
# 	Processing sample dset_target_imgs, with id=341
# 	Processing sample dset_target_imgs, with id=699
# 	Processing sample dset_target_imgs, with id=769
# 	Processing sample dset_target_imgs, with id=427
# 	Processing sample dset_target_imgs, with id=337
# 	Processing sample dset_target_imgs, with id=296
# 	Processing sample dset_target_imgs, with id=899
# 	Processing sample dset_target_imgs, with id=459
# 	Processing sample dset_target_imgs, with id=386
# 	Processing sample dset_target_imgs, with id=387
# 	Processing sample dset_target_imgs, with id=159
# 	Processing sample dset_target_imgs, with id=174
# 	Processing sample dset_target_imgs, with id=808
# 	Processing sample dset_target_imgs, with id=125
# 	Processing sample dset_target_imgs, with id=140
# 	Processing sample dset_target_imgs, with id=328
# 	Processing sample dset_target_imgs, with id=489
# 	Processing sample dset_target_imgs, with id=316
# 	Processing sample dset_target_imgs, with id=601
# 	Processing sample dset_target_imgs, with id=852
# 	Processing sample dset_target_imgs, with id=893
# 	Processing sample dset_target_imgs, with id=454
# 	Processing sample dset_target_imgs, with id=410
# 	Processing sample dset_target_imgs, with id=552
# 	Processing sample dset_target_imgs, with id=842
# 	Processing sample dset_target_imgs, with id=308
# 	Processing sample dset_target_imgs, with id=76
# 	Processing sample dset_target_imgs, with id=435
# 	Processing sample dset_target_imgs, with id=853
# 	Processing sample dset_target_imgs, with id=827
# 	Processing sample dset_target_imgs, with id=322
# 	Processing sample dset_target_imgs, with id=829
# 	Processing sample dset_target_imgs, with id=886
# 	Processing sample dset_target_imgs, with id=115
# 	Processing sample dset_target_imgs, with id=19
# 	Processing sample dset_target_imgs, with id=23
# 	Processing sample dset_target_imgs, with id=238
# 	Processing sample dset_target_imgs, with id=425
# 	Processing sample dset_target_imgs, with id=62
# 	Processing sample dset_target_imgs, with id=405
# 	Processing sample dset_target_imgs, with id=171
# 	Processing sample dset_target_imgs, with id=13
# 	Processing sample dset_target_imgs, with id=225
# 	Processing sample dset_target_imgs, with id=0
# 	Processing sample dset_target_imgs, with id=164
# 	Processing sample dset_target_imgs, with id=300
# 	Processing sample dset_target_imgs, with id=921
# 	Processing sample dset_target_imgs, with id=240
# 	Processing sample dset_target_imgs, with id=431
# 	Processing sample dset_target_imgs, with id=803
# 	Processing sample dset_target_imgs, with id=366
# 	Processing sample dset_target_imgs, with id=698
# 	Processing sample dset_target_imgs, with id=928
# 	Processing sample dset_target_imgs, with id=590
# 	Processing sample dset_target_imgs, with id=144
# 	Processing sample dset_target_imgs, with id=458
# 	Processing sample dset_target_imgs, with id=706
# 	Processing sample dset_target_imgs, with id=157
# 	Processing sample dset_target_imgs, with id=207
# 	Processing sample dset_target_imgs, with id=187
# 	Processing sample dset_target_imgs, with id=450
# 	Processing sample dset_target_imgs, with id=692
# 	Processing sample dset_target_imgs, with id=150
# 	Processing sample dset_target_imgs, with id=348
# 	Processing sample dset_target_imgs, with id=809
# 	Processing sample dset_target_imgs, with id=570
# 	Processing sample dset_target_imgs, with id=255
# 	Processing sample dset_target_imgs, with id=524
# 	Processing sample dset_target_imgs, with id=381
# 	Processing sample dset_target_imgs, with id=594
# 	Processing sample dset_target_imgs, with id=864
# 	Processing sample dset_target_imgs, with id=709
# 	Processing sample dset_target_imgs, with id=667
# 	Processing sample dset_target_imgs, with id=478
# 	Processing sample dset_target_imgs, with id=618
# 	Processing sample dset_target_imgs, with id=754
# 	Processing sample dset_target_imgs, with id=682
# 	Processing sample dset_target_imgs, with id=445
# 	Processing sample dset_target_imgs, with id=693
# 	Processing sample dset_target_imgs, with id=505
# 	Processing sample dset_target_imgs, with id=663
# 	Processing sample dset_target_imgs, with id=167
# 	Processing sample dset_target_imgs, with id=251
# 	Processing sample dset_target_imgs, with id=468
# 	Processing sample dset_target_imgs, with id=608
# 	Processing sample dset_target_imgs, with id=737
# 	Processing sample dset_target_imgs, with id=330
# 	Processing sample dset_target_imgs, with id=659
# 	Processing sample dset_target_imgs, with id=175
# 	Processing sample dset_target_imgs, with id=675
# 	Processing sample dset_target_imgs, with id=401
# 	Processing sample dset_target_imgs, with id=831
# 	Processing sample dset_target_imgs, with id=565
# 	Processing sample dset_target_imgs, with id=419
# 	Processing sample dset_target_imgs, with id=41
# 	Processing sample dset_target_imgs, with id=298
# 	Processing sample dset_target_imgs, with id=766
# 	Processing sample dset_target_imgs, with id=42
# 	Processing sample dset_target_imgs, with id=849
# 	Processing sample dset_target_imgs, with id=539
# 	Processing sample dset_target_imgs, with id=368
# 	Processing sample dset_target_imgs, with id=634
# 	Processing sample dset_target_imgs, with id=22
# 	Processing sample dset_target_imgs, with id=50
# 	Processing sample dset_target_imgs, with id=353
# 	Processing sample dset_target_imgs, with id=181
# 	Processing sample dset_target_imgs, with id=55
# 	Processing sample dset_target_imgs, with id=466
# 	Processing sample dset_target_imgs, with id=304
# 	Processing sample dset_target_imgs, with id=302
# 	Processing sample dset_target_imgs, with id=520
# 	Processing sample dset_target_imgs, with id=147
# 	Processing sample dset_target_imgs, with id=463
# 	Processing sample dset_target_imgs, with id=748
# 	Processing sample dset_target_imgs, with id=44
# 	Processing sample dset_target_imgs, with id=176
# 	Processing sample dset_target_imgs, with id=237
# 	Processing sample dset_target_imgs, with id=943
# 	Processing sample dset_target_imgs, with id=681
# 	Processing sample dset_target_imgs, with id=18
# 	Processing sample dset_target_imgs, with id=77
# 	Processing sample dset_target_imgs, with id=504
# 	Processing sample dset_target_imgs, with id=851
# 	Processing sample dset_target_imgs, with id=917
# 	Processing sample dset_target_imgs, with id=702
# 	Processing sample dset_target_imgs, with id=285
# 	Processing sample dset_target_imgs, with id=195
# 	Processing sample dset_target_imgs, with id=299
# 	Processing sample dset_target_imgs, with id=501
# 	Processing sample dset_target_imgs, with id=841
# 	Processing sample dset_target_imgs, with id=650
# 	Processing sample dset_target_imgs, with id=615
# 	Processing sample dset_target_imgs, with id=757
# 	Processing sample dset_target_imgs, with id=146
# 	Processing sample dset_target_imgs, with id=521
# 	Processing sample dset_target_imgs, with id=900
# 	Processing sample dset_target_imgs, with id=788
# 	Processing sample dset_target_imgs, with id=307
# 	Processing sample dset_target_imgs, with id=394
# 	Processing sample dset_target_imgs, with id=440
# 	Processing sample dset_target_imgs, with id=236
# 	Processing sample dset_target_imgs, with id=91
# 	Processing sample dset_target_imgs, with id=48
# 	Processing sample dset_target_imgs, with id=276
# 	Processing sample dset_target_imgs, with id=636
# 	Processing sample dset_target_imgs, with id=783
# 	Processing sample dset_target_imgs, with id=301
# 	Processing sample dset_target_imgs, with id=273
# 	Processing sample dset_target_imgs, with id=293
# 	Processing sample dset_target_imgs, with id=461
# 	Processing sample dset_target_imgs, with id=173
# 	Processing sample dset_target_imgs, with id=297
# 	Processing sample dset_target_imgs, with id=408
# 	Processing sample dset_target_imgs, with id=224
# 	Processing sample dset_target_imgs, with id=739
# 	Processing sample dset_target_imgs, with id=502
# 	Processing sample dset_target_imgs, with id=59
# 	Processing sample dset_target_imgs, with id=567
# 	Processing sample dset_target_imgs, with id=551
# 	Processing sample dset_target_imgs, with id=762
# 	Processing sample dset_target_imgs, with id=210
# 	Processing sample dset_target_imgs, with id=640
# 	Processing sample dset_target_imgs, with id=611
# 	Processing sample dset_target_imgs, with id=714
# 	Processing sample dset_target_imgs, with id=306
# 	Processing sample dset_target_imgs, with id=254
# 	Processing sample dset_target_imgs, with id=616
# 	Processing sample dset_target_imgs, with id=550
# 	Processing sample dset_target_imgs, with id=572
# 	Processing sample dset_target_imgs, with id=549
# 	Processing sample dset_target_imgs, with id=389
# 	Processing sample dset_target_imgs, with id=257
# 	Processing sample dset_target_imgs, with id=93
# 	Processing sample dset_target_imgs, with id=334
# 	Processing sample dset_target_imgs, with id=622
# 	Processing sample dset_target_imgs, with id=310
# 	Processing sample dset_target_imgs, with id=102
# 	Processing sample dset_target_imgs, with id=820
# 	Processing sample dset_target_imgs, with id=72
# 	Processing sample dset_target_imgs, with id=516
# 	Processing sample dset_target_imgs, with id=180
# 	Processing sample dset_target_imgs, with id=244
# 	Processing sample dset_target_imgs, with id=931
# 	Processing sample dset_target_imgs, with id=785
# 	Processing sample dset_target_imgs, with id=192
# 	Processing sample dset_target_imgs, with id=183
# 	Processing sample dset_target_imgs, with id=509
# 	Processing sample dset_target_imgs, with id=711
# 	Processing sample dset_target_imgs, with id=204
# 	Processing sample dset_target_imgs, with id=561
# 	Processing sample dset_target_imgs, with id=666
# 	Processing sample dset_target_imgs, with id=595
# 	Processing sample dset_target_imgs, with id=460
# 	Processing sample dset_target_imgs, with id=719
# 	Processing sample dset_target_imgs, with id=587
# 	Processing sample dset_target_imgs, with id=832
# 	Processing sample dset_target_imgs, with id=591
# 	Processing sample dset_target_imgs, with id=796
# 	Processing sample dset_target_imgs, with id=420
# 	Processing sample dset_target_imgs, with id=758
# 	Processing sample dset_target_imgs, with id=606
# 	Processing sample dset_target_imgs, with id=945
# 	Processing sample dset_target_imgs, with id=525
# 	Processing sample dset_target_imgs, with id=722
# 	Processing sample dset_target_imgs, with id=895
# 	Processing sample dset_target_imgs, with id=710
# 	Processing sample dset_target_imgs, with id=631
# 	Processing sample dset_target_imgs, with id=53
# 	Processing sample dset_target_imgs, with id=112
# 	Processing sample dset_target_imgs, with id=25
# 	Processing sample dset_target_imgs, with id=309
# 	Processing sample dset_target_imgs, with id=750
# 	Processing sample dset_target_imgs, with id=485
# 	Processing sample dset_target_imgs, with id=342
# 	Processing sample dset_target_imgs, with id=845
# 	Processing sample dset_target_imgs, with id=691
# 	Processing sample dset_target_imgs, with id=812
# 	Processing sample dset_target_imgs, with id=479
# 	Processing sample dset_target_imgs, with id=165
# 	Processing sample dset_target_imgs, with id=697
# 	Processing sample dset_target_imgs, with id=359
# 	Processing sample dset_target_imgs, with id=746
# 	Processing sample dset_target_imgs, with id=226
# 	Processing sample dset_target_imgs, with id=935
# 	Processing sample dset_target_imgs, with id=65
# 	Processing sample dset_target_imgs, with id=442
# 	Processing sample dset_target_imgs, with id=327
# 	Processing sample dset_target_imgs, with id=888
# 	Processing sample dset_target_imgs, with id=932
# 	Processing sample dset_target_imgs, with id=848
# 	Processing sample dset_target_imgs, with id=496
# 	Processing sample dset_target_imgs, with id=120
# 	Processing sample dset_target_imgs, with id=790
# 	Processing sample dset_target_imgs, with id=506
# 	Processing sample dset_target_imgs, with id=940
# 	Processing sample dset_target_imgs, with id=186
# 	Processing sample dset_target_imgs, with id=674
# 	Processing sample dset_target_imgs, with id=272
# 	Processing sample dset_target_imgs, with id=453
# 	Processing sample dset_target_imgs, with id=862
# 	Processing sample dset_target_imgs, with id=537
# 	Processing sample dset_target_imgs, with id=16
# 	Processing sample dset_target_imgs, with id=404
# 	Processing sample dset_target_imgs, with id=760
# 	Processing sample dset_target_imgs, with id=814
# 	Processing sample dset_target_imgs, with id=248
# 	Processing sample dset_target_imgs, with id=481
# 	Processing sample dset_target_imgs, with id=708
# 	Processing sample dset_target_imgs, with id=443
# 	Processing sample dset_target_imgs, with id=57
# 	Processing sample dset_target_imgs, with id=916
# 	Processing sample dset_target_imgs, with id=657
# 	Processing sample dset_target_imgs, with id=163
# 	Processing sample dset_target_imgs, with id=512
# 	Processing sample dset_target_imgs, with id=629
# 	Processing sample dset_target_imgs, with id=670
# 	Processing sample dset_target_imgs, with id=141
# 	Processing sample dset_target_imgs, with id=114
# 	Processing sample dset_target_imgs, with id=736
# 	Processing sample dset_target_imgs, with id=109
# 	Processing sample dset_target_imgs, with id=339
# 	Processing sample dset_target_imgs, with id=28
# 	Processing sample dset_target_imgs, with id=325
# 	Processing sample dset_target_imgs, with id=36
# 	Processing sample dset_target_imgs, with id=775
# 	Processing sample dset_target_imgs, with id=881
# 	Processing sample dset_target_imgs, with id=352
# 	Processing sample dset_target_imgs, with id=203
# 	Processing sample dset_target_imgs, with id=553
# 	Processing sample dset_target_imgs, with id=471
# 	Processing sample dset_target_imgs, with id=61
# 	Processing sample dset_target_imgs, with id=90
# 	Processing sample dset_target_imgs, with id=208
# 	Processing sample dset_target_imgs, with id=797
# 	Processing sample dset_target_imgs, with id=422
# 	Processing sample dset_target_imgs, with id=896
# 	Processing sample dset_target_imgs, with id=168
# 	Processing sample dset_target_imgs, with id=412
# 	Processing sample dset_target_imgs, with id=585
# 	Processing sample dset_target_imgs, with id=246
# 	Processing sample dset_target_imgs, with id=635
# 	Processing sample dset_target_imgs, with id=914
# 	Processing sample dset_target_imgs, with id=560
# 	Processing sample dset_target_imgs, with id=51
# 	Processing sample dset_target_imgs, with id=651
# 	Processing sample dset_target_imgs, with id=573
# 	Processing sample dset_target_imgs, with id=883
# 	Processing sample dset_target_imgs, with id=545
# 	Processing sample dset_target_imgs, with id=54
# 	Processing sample dset_target_imgs, with id=878
# 	Processing sample dset_target_imgs, with id=718
# 	Processing sample dset_target_imgs, with id=528
# 	Processing sample dset_target_imgs, with id=696
# 	Processing sample dset_target_imgs, with id=286
# 	Processing sample dset_target_imgs, with id=871
# 	Processing sample dset_target_imgs, with id=230
# 	Processing sample dset_target_imgs, with id=598
# 	Processing sample dset_target_imgs, with id=397
# 	Processing sample dset_target_imgs, with id=378
# 	Processing sample dset_target_imgs, with id=542
# 	Processing sample dset_target_imgs, with id=274
# 	Processing sample dset_target_imgs, with id=533
# 	Processing sample dset_target_imgs, with id=229
# 	Processing sample dset_target_imgs, with id=677
# 	Processing sample dset_target_imgs, with id=759
# 	Processing sample dset_target_imgs, with id=83
# 	Processing sample dset_target_imgs, with id=672
# 	Processing sample dset_target_imgs, with id=911
# 	Processing sample dset_target_imgs, with id=33
# 	Processing sample dset_target_imgs, with id=835
# 	Processing sample dset_target_imgs, with id=612
# 	Processing sample dset_target_imgs, with id=417
# 	Processing sample dset_target_imgs, with id=793
# 	Processing sample dset_target_imgs, with id=589
# 	Processing sample dset_target_imgs, with id=6
# 	Processing sample dset_target_imgs, with id=880
# 	Processing sample dset_target_imgs, with id=335
# 	Processing sample dset_target_imgs, with id=452
# 	Processing sample dset_target_imgs, with id=660
# 	Processing sample dset_target_imgs, with id=487
# 	Processing sample dset_target_imgs, with id=126
# 	Processing sample dset_target_imgs, with id=822
# 	Processing sample dset_target_imgs, with id=305
# 	Processing sample dset_target_imgs, with id=52
# 	Processing sample dset_target_imgs, with id=271
# 	Processing sample dset_target_imgs, with id=376
# 	Processing sample dset_target_imgs, with id=74
# 	Processing sample dset_target_imgs, with id=707
# 	Processing sample dset_target_imgs, with id=937
# 	Processing sample dset_target_imgs, with id=80
# 	Processing sample dset_target_imgs, with id=372
# 	Processing sample dset_target_imgs, with id=95
# 	Processing sample dset_target_imgs, with id=934
# 	Processing sample dset_target_imgs, with id=326
# 	Processing sample dset_target_imgs, with id=245
# 	Processing sample dset_target_imgs, with id=267
# 	Processing sample dset_target_imgs, with id=665
# 	Processing sample dset_target_imgs, with id=771
# 	Processing sample dset_target_imgs, with id=543
# 	Processing sample dset_target_imgs, with id=12
# 	Processing sample dset_target_imgs, with id=332
# 	Processing sample dset_target_imgs, with id=498
# 	Processing sample dset_target_imgs, with id=456
# 	Processing sample dset_target_imgs, with id=508
# 	Processing sample dset_target_imgs, with id=413
# 	Processing sample dset_target_imgs, with id=24
# 	Processing sample dset_target_imgs, with id=116
# 	Processing sample dset_target_imgs, with id=429
# 	Processing sample dset_target_imgs, with id=39
# 	Processing sample dset_target_imgs, with id=121
# 	Processing sample dset_target_imgs, with id=438
# 	Processing sample dset_target_imgs, with id=807
# 	Processing sample dset_target_imgs, with id=436
# 	Processing sample dset_target_imgs, with id=922
# 	Processing sample dset_target_imgs, with id=891
# 	Processing sample dset_target_imgs, with id=374
# 	Processing sample dset_target_imgs, with id=805
# 	Processing sample dset_target_imgs, with id=843
# 	Processing sample dset_target_imgs, with id=804
# 	Processing sample dset_target_imgs, with id=929
# 	Processing sample dset_target_imgs, with id=738
# 	Processing sample dset_target_imgs, with id=860
# 	Processing sample dset_target_imgs, with id=315
# 	Processing sample dset_target_imgs, with id=717
# 	Processing sample dset_target_imgs, with id=930
# 	Processing sample dset_target_imgs, with id=473
# 	Processing sample dset_target_imgs, with id=846
# 	Processing sample dset_target_imgs, with id=792
# 	Processing sample dset_target_imgs, with id=806
# 	Processing sample dset_target_imgs, with id=755
# 	Processing sample dset_target_imgs, with id=277
# 	Processing sample dset_target_imgs, with id=153
# 	Processing sample dset_target_imgs, with id=361
# 	Processing sample dset_target_imgs, with id=534
# 	Processing sample dset_target_imgs, with id=67
# 	Processing sample dset_target_imgs, with id=106
# 	Processing sample dset_target_imgs, with id=223
# 	Processing sample dset_target_imgs, with id=360
# 	Processing sample dset_target_imgs, with id=610
# 	Processing sample dset_target_imgs, with id=919
# 	Processing sample dset_target_imgs, with id=705
# 	Processing sample dset_target_imgs, with id=497
# 	Processing sample dset_target_imgs, with id=26
# 	Processing sample dset_target_imgs, with id=356
# 	Processing sample dset_target_imgs, with id=701
# 	Processing sample dset_target_imgs, with id=678
# 	Processing sample dset_target_imgs, with id=279
# 	Processing sample dset_target_imgs, with id=558
# 	Processing sample dset_target_imgs, with id=859
# 	Processing sample dset_target_imgs, with id=467
# 	Processing sample dset_target_imgs, with id=586
# (15713, 256, 256, 3)
# (15713, 288, 288, 1)
# (15713,)
# CPU times: user 17min 27s, sys: 29.5 s, total: 17min 56s
# Wall time: 19min 11s

# %%
train_h5py.close()

# %%
val_h5py = h5py.File("data/val_all_classes.h5",mode='w')
dset_target_imgs = val_h5py.create_dataset("target_imgs", (0, PATCH_SIZE + 2*PAD_SIZE, PATCH_SIZE + 2*PAD_SIZE, 1),
                                             maxshape=(None, PATCH_SIZE + 2*PAD_SIZE, PATCH_SIZE + 2*PAD_SIZE, 1),
                                             dtype=np.uint8, shuffle=True, compression="gzip")

dset_imgs = val_h5py.create_dataset("imgs", (0, PATCH_SIZE, PATCH_SIZE, 3),
                                      maxshape=(None, PATCH_SIZE, PATCH_SIZE, 3),
                                      dtype=np.uint8, shuffle=True, compression="gzip")

dset_counts = val_h5py.create_dataset("counts", (0,), maxshape=(None,),
                                        dtype=np.uint8, shuffle=True, compression="gzip")

# %%
# %%time

create_datasets(ID_VAL_IMGS, dset_target_imgs, dset_imgs, dset_counts)
print(dset_imgs.shape)
print(dset_target_imgs.shape)
print(dset_counts.shape)

val_h5py.close()
# Out:
# 	Processing sample dset_target_imgs, with id=602
# 	Processing sample dset_target_imgs, with id=444
# 	Processing sample dset_target_imgs, with id=944
# 	Processing sample dset_target_imgs, with id=117
# 	Processing sample dset_target_imgs, with id=15
# 	Processing sample dset_target_imgs, with id=47
# 	Processing sample dset_target_imgs, with id=763
# 	Processing sample dset_target_imgs, with id=873
# 	Processing sample dset_target_imgs, with id=802
# 	Processing sample dset_target_imgs, with id=865
# 	Processing sample dset_target_imgs, with id=795
# 	Processing sample dset_target_imgs, with id=724
# 	Processing sample dset_target_imgs, with id=673
# 	Processing sample dset_target_imgs, with id=731
# 	Processing sample dset_target_imgs, with id=679
# 	Processing sample dset_target_imgs, with id=182
# 	Processing sample dset_target_imgs, with id=791
# 	Processing sample dset_target_imgs, with id=686
# 	Processing sample dset_target_imgs, with id=5
# 	Processing sample dset_target_imgs, with id=8
# 	Processing sample dset_target_imgs, with id=776
# 	Processing sample dset_target_imgs, with id=628
# 	Processing sample dset_target_imgs, with id=575
# 	Processing sample dset_target_imgs, with id=782
# 	Processing sample dset_target_imgs, with id=555
# 	Processing sample dset_target_imgs, with id=398
# 	Processing sample dset_target_imgs, with id=588
# 	Processing sample dset_target_imgs, with id=190
# 	Processing sample dset_target_imgs, with id=777
# 	Processing sample dset_target_imgs, with id=727
# 	Processing sample dset_target_imgs, with id=884
# 	Processing sample dset_target_imgs, with id=939
# 	Processing sample dset_target_imgs, with id=540
# 	Processing sample dset_target_imgs, with id=260
# 	Processing sample dset_target_imgs, with id=329
# 	Processing sample dset_target_imgs, with id=733
# 	Processing sample dset_target_imgs, with id=861
# 	Processing sample dset_target_imgs, with id=854
# 	Processing sample dset_target_imgs, with id=172
# 	Processing sample dset_target_imgs, with id=743
# 	Processing sample dset_target_imgs, with id=554
# 	Processing sample dset_target_imgs, with id=866
# 	Processing sample dset_target_imgs, with id=818
# 	Processing sample dset_target_imgs, with id=583
# 	Processing sample dset_target_imgs, with id=728
# 	Processing sample dset_target_imgs, with id=633
# 	Processing sample dset_target_imgs, with id=938
# 	Processing sample dset_target_imgs, with id=462
# 	Processing sample dset_target_imgs, with id=131
# 	Processing sample dset_target_imgs, with id=723
# 	Processing sample dset_target_imgs, with id=753
# 	Processing sample dset_target_imgs, with id=920
# 	Processing sample dset_target_imgs, with id=218
# 	Processing sample dset_target_imgs, with id=367
# 	Processing sample dset_target_imgs, with id=685
# 	Processing sample dset_target_imgs, with id=198
# 	Processing sample dset_target_imgs, with id=439
# 	Processing sample dset_target_imgs, with id=620
# 	Processing sample dset_target_imgs, with id=199
# 	Processing sample dset_target_imgs, with id=923
# 	Processing sample dset_target_imgs, with id=94
# 	Processing sample dset_target_imgs, with id=75
# 	Processing sample dset_target_imgs, with id=266
# 	Processing sample dset_target_imgs, with id=703
# 	Processing sample dset_target_imgs, with id=918
# 	Processing sample dset_target_imgs, with id=143
# 	Processing sample dset_target_imgs, with id=73
# 	Processing sample dset_target_imgs, with id=29
# 	Processing sample dset_target_imgs, with id=323
# 	Processing sample dset_target_imgs, with id=197
# (1247, 256, 256, 3)
# (1247, 288, 288, 1)
# (1247,)
# CPU times: user 1min 11s, sys: 2.78 s, total: 1min 14s
# Wall time: 1min 19s
